# %%
pwd
# Out:
# '/freya/u/sqyu/AstroLab/TNG/code/tree'

# %%
import numpy as np
type = 'Hydro'
load_dir = f'/freya/u/sqyu/AstroLab/TNG/result/DMhalo_mass_table_new/{type}-Arepo/MTNG-L500-4320-A/'

data_64 = np.load(f'{load_dir}/snap_64_FPGrMass.npy')
data_151 = np.load(f'{load_dir}/snap_151_FPGrMass.npy')
data_214 = np.load(f'{load_dir}/snap_214_FPGrMass.npy')
data_264 = np.load(f'{load_dir}/snap_264_FPGrMass.npy')

for i in range(100):
    idx = -i
    print(data_64[idx],
          data_151[idx], 
          data_214[idx], 
          data_264[idx])
# Out:
# 535.4507446289062 668.1706
# 325.998779296875 636.7813
# 425.548583984375 611.27924
# 418.3458251953125 664.4496
# 416.69793701171875 649.9776
# 245.798095703125 655.1471
# 570.99951171875 637.5521
# 459.5956726074219 576.076
# 212.3490447998047 500.84552
# 399.2225646972656 516.487
# 248.32305908203125 371.18225
# 474.5328063964844 640.52893
# 350.37127685546875 641.5389
# 387.7672424316406 646.5091
# 526.6665649414062 587.93005
# 480.57940673828125 636.75476
# 247.95095825195312 577.086
# 496.2341613769531 660.5824
# 236.58865356445312 597.95013
# 239.7116241455078 312.51016
# 106.97852325439453 624.0901
# 439.1302185058594 636.4757
# 337.1617431640625 622.296
# 480.5528259277344 658.90796
# 499.8089599609375 649.7915
# 197.38534545898438 568.0227
# 473.4430847167969 650.7218
# 646.628662109375 604.4486
# 117.22454071044922 469.0842
# 329.6267395019531 400.64453
# 418.89068603515625 632.768
# 457.20361328125 648.7284
# 190.78057861328125 601.711
# 167.56423950195312 630.30945
# ...
